# %% [markdown]
# # Neural Baseline for NER with LSTM
#
# This notebook runs the `lstm.py` script for training a neural baseline model for named entity recognition using LSTM.

# %%
# %pip install wandb
import wandb
wandb.login()

# %%
dir_path = "/content/drive/Othercomputers/Mein Computer/dl-nlp_project_named-entity-recognition/"
train_path = dir_path + "data/train.json"
test_path = dir_path + "data/test.json"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
lstm_path = "/content/drive/Othercomputers/Mein Computer/dl-nlp_project_named-entity-recognition/lstm.py"
# %run "{lstm_path}" --train_path "{train_path}" --test_path "{test_path}"

# %%
feed_forward_path = "/content/drive/Othercomputers/Mein Computer/dl-nlp_project_named-entity-recognition/feed_forward_NN.py"
# %run "{feed_forward_path}" --train_path "{train_path}" --test_path "{test_path}"

# %%
rnn_path = "rnn.py"
# %run "{rnn_path}" --train_path "{train_path}" --test_path "{test_path}"
# Out:
# torch.Size([32, 181])
# ...

# %%
wandb.finish()
