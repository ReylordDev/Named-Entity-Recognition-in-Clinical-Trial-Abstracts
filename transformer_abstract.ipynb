# %%
using_wandb = False
using_colab = True

# %%
pmid_post_processing = False
data_augmentation = False
section_headers = False

# %%
if using_wandb:
  # %pip install wandb -q
  import wandb
  wandb.login()

# %%
if using_colab:
    from google.colab import drive

    drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
model_checkpoint = "distilbert-base-uncased"
# model_checkpoint = 'michiyasunaga/BioLinkBERT-large'
# model_checkpoint = 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract'
model_name = "custom_model_3"

# %%
# %pip install transformers -q
# %pip install accelerate -U -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 33.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.2 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
from torch.nn import BCEWithLogitsLoss
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import f1_score
from transformers import AutoTokenizer, get_scheduler
import importlib
import json
import random
import os
from importlib import reload
from tqdm.auto import tqdm

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
if using_colab:
    # dir_path = (
    #     "drive/Othercomputers/my_computer/dl-nlp_project_named-entity-recognition/"
    # )
    dir_path = "drive/MyDrive/dl-nlp_project_named-entity-recognition/"
    module_path = dir_path.replace("/", ".")
    # imports
    data_module = importlib.import_module(module_path + "data")
    load_data = data_module.load_data
    extract_sentences_and_labels = data_module.extract_sentences_and_labels
    generate_label_vocab = data_module.generate_label_vocab
    split_data = data_module.split_data

else:
    dir_path = "./"
    from data import (
        load_data,
        extract_sentences_and_labels,
        generate_label_vocab,
        split_data,
    )

# %%
train_file_path = dir_path + "data/train.json"
test_file_path = dir_path + "data/test.json"

# %%
train_data, test_data = load_data(train_file_path, test_file_path)
train_sentences, train_raw_labels = extract_sentences_and_labels(train_data)
test_sentences, test_raw_labels = extract_sentences_and_labels(test_data)

# Generate label vocabulary
label_vocab = generate_label_vocab(train_raw_labels + test_raw_labels)

# %%
SPECIAL_TOKEN = "<SPC>"


class Labels:
    def __init__(self, num_classes, names):
        super().__init__()
        self.names = names
        print(self.names)
        self.num_classes = num_classes

    def __getitem__(self, label_vector):
        return [self.names[idx] for idx, value in enumerate(label_vector) if value == 1]

    def decode(self, label_vector):
        return self.__getitem__(label_vector)

    def encode(self, names):
        indexes = []
        for name in names:
            index = self.names.index(name)
            indexes.append(index)
        tensor = torch.zeros(self.num_classes)
        for index in indexes:
            tensor[index] = 1
        return tensor

    def tensor2sentence(self, tensor):
        return [self.decode(vector) for vector in tensor]


ner_labels = Labels(
    num_classes=len(label_vocab) + 1, names=label_vocab + [SPECIAL_TOKEN]
)
id2label = ner_labels.decode
label2id = ner_labels.encode
ner_labels.num_classes
# Out:
# ['NumberAffected', 'PercentageAffected', 'NumberPatientsArm', 'ObservedResult', 'CTDesign', 'FinalNumPatientsArm', 'DoseDescription', 'ConfIntervalDiff', 'TimePoint', 'Journal', 'ConfIntervalChangeValue', 'Country', 'Precondition', 'Title', 'PMID', 'SdDevChangeValue', 'ConclusionComment', 'NumberPatientsCT', 'ResultMeasuredValue', 'Drug', 'RelativeChangeValue', 'SdDevBL', 'AllocationRatio', 'DiffGroupAbsValue', 'MinAge', 'AvgAge', 'PublicationYear', 'DoseValue', 'AggregationMethod', 'ObjectiveDescription', 'Author', 'PvalueDiff', 'Frequency', 'PValueChangeValue', 'SubGroupDescription', 'SdDevResValue', '<SPC>']
# 37

# %%
class NERDataset(Dataset):
    def __init__(self, abstracts):
        self.abstracts = abstracts
        self.count = len(abstracts)

    def __getitem__(self, idx):
        return self.abstracts[idx]

    def __len__(self):
        return self.count

    def tokenize(self):
        for abstract in self.abstracts:
            tokenized_inputs = tokenize_and_align_labels(
                [sentence["tokens"] for sentence in abstract["sentences"]],
                [sentence["labels_list"] for sentence in abstract["sentences"]],
            )
            for key in tokenized_inputs.keys():
                abstract[key] = torch.Tensor(tokenized_inputs[key]).to(device)

# %%
def extract_abstracts(json_file_path):
    with open(json_file_path, "r") as file:
        data = json.load(file)

    abstracts = []

    for entry in data:
        abstract = {"id": entry["abstract_id"], "sentences": []}
        for sentence in entry["sentences"]:
            tokens = sentence.pop("words")

            entities = sentence.pop("entities")
            labels_list = [torch.zeros(ner_labels.num_classes) for x in tokens]
            for label_entity in entities:
                start_pos = label_entity["start_pos"]
                end_pos = label_entity["end_pos"]
                label = label_entity["label"]
                label_id = label2id([label]).argmax().item()
                for label_index in range(start_pos, end_pos + 1):
                    labels_list[label_index][label_id] = 1
            sentence["tokens"] = tokens
            sentence["labels_list"] = labels_list
            sentence["id"] = sentence.pop("sentence_id")
            abstract["sentences"].append(sentence)
        abstract["length"] = len(abstract["sentences"])
        abstract["sentence_length"] = np.sum(
            [len(sentence["tokens"]) for sentence in abstract["sentences"]]
        )
        abstracts.append(abstract)

    return abstracts

# %%
def split_abstracts(abstracts, val_split=0.2):
    random.shuffle(abstracts)
    num_val = int(len(abstracts) * val_split)
    val_abstracts = abstracts[:num_val]
    train_abstracts = abstracts[num_val:]
    return train_abstracts, val_abstracts

# %%
abstracts = extract_abstracts(train_file_path)
train_abstracts, val_abstracts = split_abstracts(abstracts)
test_abstracts = extract_abstracts(test_file_path)

print(
    f"Train abstracts: {len(train_abstracts)}, sentences: {sum([abstract['length'] for abstract in train_abstracts])}"
)
print(
    f"Val abstracts: {len(val_abstracts)}, sentences: {sum([abstract['length'] for abstract in val_abstracts])}"
)
print(
    f"Test abstracts: {len(test_abstracts)}, sentences: {sum([abstract['length'] for abstract in test_abstracts])}"
)
# Out:
# Train abstracts: 55, sentences: 1149
# Val abstracts: 13, sentences: 296
# Test abstracts: 20, sentences: 385

# %%
datasets = {
    "train": NERDataset(train_abstracts),
    "val": NERDataset(val_abstracts),
    "test": NERDataset(test_abstracts),
}

print(len(datasets["train"]))
print(len(datasets["val"]))
print(len(datasets["test"]))
# Out:
# 55
# 13
# 20

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
def tokenize_and_align_labels(sentences, original_labels_lists):
    # print(f"Sentences: {sentences}")
    # print(f"OG Labels_lists: {original_labels_lists}")
    tokenized_inputs = tokenizer(
        sentences,
        is_split_into_words=True,
        padding=True
        # max_length=max_length,
        # padding="max_length",
    )
    # print(f"Tokenized_inputs: {tokenized_inputs}")
    # print(f"Length: {len(tokenized_inputs['input_ids'])}")
    # print(f"max_length: {max_length}")

    label_list = []
    for i, labels in enumerate(original_labels_lists):
        word_ids = tokenized_inputs.word_ids(
            batch_index=i
        )  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(label2id([SPECIAL_TOKEN]))
            elif word_idx != previous_word_idx:
                label_ids.append(torch.Tensor(labels[word_idx]))
            else:
                label_ids.append(label2id([SPECIAL_TOKEN]))
            previous_word_idx = word_idx

        padded_length = len(tokenized_inputs["input_ids"][i])
        for i in range(padded_length - len(label_ids)):
            label_ids.append(label2id([SPECIAL_TOKEN]))
        label_ids = torch.stack(label_ids)
        # print(f"Label_ids_shape: {label_ids.shape}")
        label_list.append(label_ids)

    # print(f"Label_list: {label_list}")
    tokenized_inputs["labels"] = torch.stack(label_list)
    return tokenized_inputs

# %%
datasets["train"].tokenize()
datasets["val"].tokenize()
datasets["test"].tokenize()

# %%
from transformers import BertForTokenClassification, DistilBertForTokenClassification


# class CustomTokenClassification(BertForTokenClassification):
class CustomTokenClassification(DistilBertForTokenClassification):
    def __init__(self, config):
        super(CustomTokenClassification, self).__init__(config)
        self.loss_fct = BCEWithLogitsLoss()

    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
        outputs = super().forward(
            input_ids=input_ids.int(), attention_mask=attention_mask.int(), **kwargs
        )

        # Check if the outputs is a dictionary and extract logits
        if isinstance(outputs, dict):
            logits = outputs.get("logits", None)
        else:  # Assume the outputs is a tuple and logits are the first element
            logits = outputs[0]

        return logits

# %%
def mask_and_flatten_logits_and_labels(logits, labels):
    mask = labels[:, :, -1] != 1
    logits = logits[mask]
    labels = labels[mask]

    flat_logits = logits.view(-1, logits.shape[-1])
    flat_labels = labels.view(-1, labels.shape[-1])
    return flat_logits, flat_labels

# %%
def flatten_list(list_of_lists):
    flattened_list = []
    for sublist in list_of_lists:
        for item in sublist:
            flattened_list.append(item)
    return flattened_list

# %%
def custom_collate(batch):
    if len(batch) != 1:
        return None
    abstract = batch[0]
    if "id" in abstract.keys():
        abstract.pop("id")
    if "sentences" in abstract.keys():
        abstract.pop("sentences")
    if "length" in abstract.keys():
        abstract.pop("length")
    if "sentence_length" in abstract.keys():
        abstract.pop("sentence_length")
    data = []
    input_ids = []
    attention_mask = []
    labels = []
    for x, y, z in zip(
        abstract["input_ids"], abstract["attention_mask"], abstract["labels"]
    ):
        input_ids_len = np.sum([len(x) for x in input_ids])
        if input_ids_len > tokenizer.max_model_input_sizes[model_checkpoint] - 100:
            print(f"input cut off at {input_ids_len}")
            data.append(
                {
                    "input_ids": torch.cat(input_ids),
                    "attention_mask": torch.cat(attention_mask),
                    "labels": torch.cat(labels),
                }
            )
            input_ids = []
            attention_mask = []
            labels = []
        input_ids_list = x.tolist()
        if 0.0 in input_ids_list:
            padding_index = input_ids_list.index(0.0)
            input_ids.append(x[:padding_index])
            attention_mask.append(y[:padding_index])
            labels.append(z[:padding_index])
        else:
            input_ids.append(x[:])
            attention_mask.append(y[:])
            labels.append(z[:])
    data.append(
        {
            "input_ids": torch.cat(input_ids),
            "attention_mask": torch.cat(attention_mask),
            "labels": torch.cat(labels),
        }
    )
    for data_object in data:
        print(data_object["input_ids"].shape)
        padding_length = (
            tokenizer.max_model_input_sizes[model_checkpoint]
            - data_object["input_ids"].shape[0]
        )
        torch.cat([data_object["input_ids"], torch.zeros(padding_length)])
        torch.cat([data_object["attention_mask"], torch.zeros(padding_length)])
        print(data_object["labels"].shape)
        torch.cat(
            [data_object["labels"], label2id([SPECIAL_TOKEN] * padding_length)]
        )  # this is wrong
        print(data_object["input_ids"].shape)
    return data

# %%
model = CustomTokenClassification.from_pretrained(
    model_checkpoint, num_labels=ner_labels.num_classes
)
model.to(device)
# Out:
# Some weights of CustomTokenClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
config = {}
config["num_epochs"] = 25
config["batch_size"] = 1
config["lr"] = 1e-4
config["num_warmup_steps"] = 0
config["model_checkpoint"] = model_checkpoint
config["section_headers"] = section_headers
config["data_augmentation"] = data_augmentation
# config["augmentations"] = augmentations
config["pmid_post_processing"] = pmid_post_processing

# %%
if using_wandb:
    wandb.init(project="DL-NLP-Clinical-Trial-NER", config=config)
    config = wandb.config

# %%
train_dataloader = DataLoader(
    datasets["train"],
    shuffle=True,
    batch_size=config["batch_size"],
    collate_fn=lambda x: custom_collate(x),
)
val_dataloader = DataLoader(
    datasets["val"],
    shuffle=True,
    batch_size=config["batch_size"],
    collate_fn=lambda x: custom_collate(x),
)

optimizer = AdamW(model.parameters(), lr=config["lr"])

num_training_steps = config["num_epochs"] * len(train_dataloader)

lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=config["num_warmup_steps"],
    num_training_steps=num_training_steps,
)

loss_fct = BCEWithLogitsLoss()

progress_bar = tqdm(range(num_training_steps))

for epoch in range(config["num_epochs"]):
    model.train()
    epoch_loss = 0.0

    for batch in train_dataloader:
        labels_list = []
        logits_list = []
        for data_object in batch:
            labels_list.append(data_object["labels"])

            logits = model(**data_object)
            logits_list.append(logits)
        foo()

        flat_logits, flat_labels = mask_and_flatten_logits_and_labels(logits, labels)

        loss = loss_fct(flat_logits, flat_labels)
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()

        epoch_loss += loss.item() * labels.size(0)

        progress_bar.update(1)

    epoch_loss = epoch_loss / len(train_dataloader)
    progress_bar.write(f"Epoch {epoch}, Loss: {epoch_loss:.3f}")

    model.eval()

    preds = []
    true_labels = []

    for batch in val_dataloader:
        labels = batch["labels"]

        with torch.no_grad():
            logits = model(**batch)

        flat_logits, flat_labels = mask_and_flatten_logits_and_labels(logits, labels)

        pred = flat_logits.heaviside(torch.tensor([0.0], device=device)).int().tolist()
        true_label = flat_labels.int().tolist()

        preds.extend(pred)
        true_labels.extend(true_label)

    f1 = f1_score(true_labels, preds, average="micro")
    progress_bar.write(f"f1 micro: {f1:.3f}")
    if using_wandb:
        wandb.log({"train_loss": epoch_loss, "micro_f1": f1, "epoch": epoch})
progress_bar.close()
model.save_pretrained(model_name)
# Out:
#   0%|          | 0/1375 [00:00<?, ?it/s]
# 437
# 470
# 482
# torch.Size([437])
# torch.Size([470])
# torch.Size([482])
# torch.Size([246])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-165-276fd75cd1cd> in <cell line: 29>()
#      37             labels_list.append(data_object['labels'])
#      38
# ---> 39             logits = model(**data_object)
#      40             logits_list.append(logits)
#      41         foo()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-111-f51dc0578cdc> in forward(self, input_ids, attention_mask, labels, **kwargs)
#      15         **kwargs
#      16     ):
# ---> 17         outputs = super().forward(
#      18             input_ids=input_ids.int(), attention_mask=attention_mask.int(), **kwargs
#      19         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1018         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1019
# -> 1020         outputs = self.distilbert(
#    1021             input_ids,
#    1022             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     605         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     606
# --> 607         embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     608
#     609         return self.transformer(
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, input_embeds)
#     133         position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
#     134
# --> 135         embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#     136         embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#     137         embeddings = self.dropout(embeddings)  # (bs, max_seq_length, dim)
#
# RuntimeError: The size of tensor a (437) must match the size of tensor b (512) at non-singleton dimension 1

# %%
label_list = ner_labels.names

test_dataloader = DataLoader(
    datasets["test"],
    shuffle=False,
    batch_size=1,
    collate_fn=lambda x: custom_collate(x),
)
model.eval()

preds = []
true_labels = []

dataloader = test_dataloader
progress_bar = tqdm(range(len(dataloader)))
for batch in dataloader:
    labels = batch["labels"]

    with torch.no_grad():
        logits = model(**batch)

    flat_logits, flat_labels = mask_and_flatten_logits_and_labels(logits, labels)

    pred = flat_logits.heaviside(torch.tensor([0.0], device=device)).int().tolist()
    true_label = flat_labels.int().tolist()

    preds.extend(pred)
    true_labels.extend(true_label)

    progress_bar.update(1)

f1 = f1_score(true_labels, preds, average="micro")
f1_per_class = f1_score(true_labels, preds, average=None, zero_division=1)
for label, score in zip(label_list, f1_per_class):
    print(f"{label}: {score:.4f}")
progress_bar.write(f"f1 micro: {f1}")
if using_wandb:
    wandb.log({"test_micro_f1": f1})
    per_class_table = wandb.Table(columns=label_list, data=[f1_per_class])
    wandb.log({"F1_per_label": per_class_table})
    wandb.finish()
progress_bar.close()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# NumberAffected: 0.0000
# PercentageAffected: 0.9465
# NumberPatientsArm: 0.8000
# ObservedResult: 0.1679
# CTDesign: 0.0000
# FinalNumPatientsArm: 1.0000
# DoseDescription: 0.1282
# ConfIntervalDiff: 0.7466
# TimePoint: 0.5424
# Journal: 0.9764
# ConfIntervalChangeValue: 0.0000
# Country: 0.0000
# Precondition: 0.3851
# Title: 0.9587
# PMID: 1.0000
# SdDevChangeValue: 0.0000
# ConclusionComment: 0.9092
# NumberPatientsCT: 0.7586
# ResultMeasuredValue: 0.5882
# Drug: 1.0000
# RelativeChangeValue: 1.0000
# SdDevBL: 0.0000
# AllocationRatio: 0.9730
# DiffGroupAbsValue: 0.6220
# MinAge: 0.0000
# AvgAge: 0.0000
# PublicationYear: 0.8696
# DoseValue: 0.6667
# AggregationMethod: 1.0000
# ObjectiveDescription: 0.8955
# Author: 0.9429
# PvalueDiff: 0.8859
# Frequency: 0.5634
# PValueChangeValue: 0.2718
# SubGroupDescription: 0.0000
# SdDevResValue: 0.3111
# <SPC>: 1.0000
# f1 micro: 0.7782091725309391

# %%
from random import randint

example_count = 30
index = randint(0, len(datasets["test"]) - example_count - 1)
print(f"Index: {index}")
examples = datasets["test"][index : index + example_count]
labels = examples["labels"]
with torch.no_grad():
    logits = model(**examples)

flat_logits, flat_labels = mask_and_flatten_logits_and_labels(logits, labels)


preds = flat_logits.heaviside(torch.tensor([0.0], device=device)).int().tolist()
true_labels = flat_labels.int().tolist()
print(len(true_label))
print(len(pred))
f1 = f1_score(true_labels, preds, average="micro")

tokens_lists = test_original_tokens[index : index + example_count]
tokens = flatten_list(tokens_lists)

for true_label, pred, token in zip(true_labels, preds, tokens):
    print(f"true:{id2label(true_label)}, pred:{id2label(pred)}, token: {token}")
print(f"Micro-F1 Score: {f1:.3f}")
# Out:
# Index: 49
# 33
# 33
# true:[], pred:[], token: A
# true:[], pred:[], token: significantly
# true:[], pred:[], token: greater
# true:[], pred:[], token: proportion
# true:[], pred:[], token: of
# true:[], pred:[], token: patients
# true:[], pred:[], token: achieved
# true:[], pred:[], token: an
# true:[], pred:[], token: A1C
# true:[], pred:[], token: <
# true:[], pred:[], token: 7
# true:[], pred:[], token: %
# true:[], pred:[], token: with
# true:[], pred:[], token: sitagliptin
# true:[], pred:[], token: (
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 47
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 0
# true:[], pred:[], token: %
# true:[], pred:[], token: )
# true:[], pred:[], token: than
# true:[], pred:[], token: with
# true:[], pred:[], token: placebo
# true:[], pred:[], token: (
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 18
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 3
# true:[], pred:[], token: %
# true:[], pred:[], token: )
# true:[], pred:[], token: .
# true:['ObservedResult'], pred:['ObservedResult'], token: There
# true:['ObservedResult'], pred:['ObservedResult'], token: was
# true:['ObservedResult'], pred:['ObservedResult'], token: no
# true:['ObservedResult'], pred:['ObservedResult'], token: increased
# true:['ObservedResult'], pred:['ObservedResult'], token: risk
# true:[], pred:['ObservedResult'], token: of
# true:[], pred:['ObservedResult'], token: hypoglycemia
# true:[], pred:['ObservedResult'], token: or
# true:[], pred:['ObservedResult'], token: gastrointestinal
# true:[], pred:['ObservedResult'], token: adverse
# true:[], pred:['ObservedResult'], token: experiences
# true:[], pred:['ObservedResult'], token: with
# true:[], pred:['ObservedResult'], token: sitagliptin
# true:[], pred:['ObservedResult'], token: compared
# true:[], pred:['ObservedResult'], token: with
# true:[], pred:['ObservedResult'], token: placebo
# true:[], pred:[], token: .
# true:[], pred:['ObservedResult'], token: Body
# true:[], pred:['ObservedResult'], token: weight
# true:['ObservedResult'], pred:['ObservedResult'], token: decreased
# true:['ObservedResult'], pred:['ObservedResult'], token: similarly
# true:['ObservedResult'], pred:['ObservedResult'], token: with
# true:['ObservedResult'], pred:['ObservedResult'], token: sitagliptin
# true:['ObservedResult'], pred:['ObservedResult'], token: and
# true:['ObservedResult'], pred:['ObservedResult'], token: placebo
# true:[], pred:['ObservedResult'], token: .
# true:[], pred:[], token: CONCLUSIONS
# true:[], pred:[], token: :
# true:['ConclusionComment'], pred:['ConclusionComment'], token: Sitagliptin
# true:['ConclusionComment'], pred:['ConclusionComment'], token: 100
# true:['ConclusionComment'], pred:['ConclusionComment'], token: mg
# true:['ConclusionComment'], pred:['ConclusionComment'], token: once
# true:['ConclusionComment'], pred:['ConclusionComment'], token: -
# true:['ConclusionComment'], pred:['ConclusionComment'], token: daily
# true:['ConclusionComment'], pred:['ConclusionComment'], token: added
# true:['ConclusionComment'], pred:['ConclusionComment'], token: to
# true:['ConclusionComment'], pred:['ConclusionComment'], token: ongoing
# true:['ConclusionComment'], pred:['ConclusionComment'], token: metformin
# true:['ConclusionComment'], pred:['ConclusionComment'], token: therapy
# true:['ConclusionComment'], pred:['ConclusionComment'], token: was
# true:['ConclusionComment'], pred:['ConclusionComment'], token: efficacious
# true:['ConclusionComment'], pred:['ConclusionComment'], token: and
# true:['ConclusionComment'], pred:['ConclusionComment'], token: well
# true:['ConclusionComment'], pred:['ConclusionComment'], token: tolerated
# true:['ConclusionComment'], pred:['ConclusionComment'], token: in
# true:['ConclusionComment'], pred:['ConclusionComment'], token: patients
# true:['ConclusionComment'], pred:['ConclusionComment'], token: with
# true:['ConclusionComment'], pred:['ConclusionComment'], token: type
# true:['ConclusionComment'], pred:['ConclusionComment'], token: 2
# true:['ConclusionComment'], pred:['ConclusionComment'], token: diabetes
# true:['ConclusionComment'], pred:['ConclusionComment'], token: who
# true:['ConclusionComment'], pred:['ConclusionComment'], token: had
# true:['ConclusionComment'], pred:['ConclusionComment'], token: inadequate
# true:['ConclusionComment'], pred:['ConclusionComment'], token: glycemic
# true:['ConclusionComment'], pred:['ConclusionComment'], token: control
# true:['ConclusionComment'], pred:['ConclusionComment'], token: with
# true:['ConclusionComment'], pred:['ConclusionComment'], token: metformin
# true:['ConclusionComment'], pred:['ConclusionComment'], token: alone
# true:['ConclusionComment'], pred:['ConclusionComment'], token: .
# true:[], pred:[], token: DOI
# true:[], pred:[], token: :
# true:[], pred:[], token: 10
# true:[], pred:[], token: .
# true:[], pred:[], token: 2337
# true:[], pred:[], token: /
# true:[], pred:[], token: dc06
# true:[], pred:[], token: -
# true:[], pred:[], token: 0706
# true:[], pred:[], token: PMID
# true:[], pred:[], token: :
# true:['PMID'], pred:['PMID'], token: 17130197
# true:[], pred:[], token: [
# true:[], pred:[], token: Indexed
# true:[], pred:[], token: for
# true:[], pred:[], token: MEDLINE
# true:[], pred:[], token: ]
# true:['Journal'], pred:['Journal'], token: Diabet
# true:['Journal'], pred:['Journal'], token: Med
# true:['Journal'], pred:['Journal'], token: .
# true:['PublicationYear'], pred:['PublicationYear'], token: 2014
# true:[], pred:[], token: Dec
# true:[], pred:[], token: ;
# true:[], pred:[], token: 31
# true:[], pred:[], token: (
# true:[], pred:[], token: 12
# true:[], pred:[], token: )
# true:[], pred:[], token: :
# true:[], pred:[], token: 1505
# true:[], pred:[], token: -
# true:[], pred:[], token: 14
# true:[], pred:[], token: .
# true:[], pred:[], token: doi
# true:[], pred:[], token: :
# true:[], pred:[], token: 10
# true:[], pred:[], token: .
# true:[], pred:[], token: 1111
# true:[], pred:[], token: /
# true:[], pred:[], token: dme
# true:[], pred:[], token: .
# true:[], pred:[], token: 12495
# true:[], pred:[], token: .
# true:[], pred:[], token: Epub
# true:[], pred:[], token: 2014
# true:[], pred:[], token: Jul
# true:[], pred:[], token: 7
# true:[], pred:[], token: .
# true:['Title'], pred:['Title'], token: Linagliptin
# true:['Title'], pred:['Title'], token: improved
# true:['Title'], pred:['Title'], token: glycaemic
# true:['Title'], pred:['Title'], token: control
# true:['Title'], pred:['Title'], token: without
# true:['Title'], pred:['Title'], token: weight
# true:['Title'], pred:['Title'], token: gain
# true:['Title'], pred:['Title'], token: or
# true:['Title'], pred:['Title'], token: hypoglycaemia
# true:['Title'], pred:['Title'], token: in
# true:['Title'], pred:['Title'], token: patients
# true:['Title'], pred:['Title'], token: with
# true:['Title'], pred:['Title'], token: type
# true:['Title'], pred:['Title'], token: 2
# true:['Title'], pred:['Title'], token: diabetes
# true:['Title'], pred:['Title'], token: inadequately
# true:['Title'], pred:['Title'], token: controlled
# true:['Title'], pred:['Title'], token: by
# true:['Title'], pred:['Title'], token: a
# true:['Title'], pred:['Title'], token: combination
# true:['Title'], pred:['Title'], token: of
# true:['Title'], pred:['Title'], token: metformin
# true:['Title'], pred:['Title'], token: and
# true:['Title'], pred:['Title'], token: pioglitazone
# true:['Title'], pred:['Title'], token: :
# true:['Title'], pred:['Title'], token: a
# true:['Title'], pred:['Title'], token: 24
# true:['Title'], pred:['Title'], token: -
# true:['Title'], pred:['Title'], token: week
# true:['Title'], pred:['Title'], token: randomized
# true:['Title'], pred:['Title'], token: ,
# true:['Title'], pred:['Title'], token: double
# true:['Title'], pred:['Title'], token: -
# true:['Title'], pred:['Title'], token: blind
# true:['Title'], pred:['Title'], token: study
# true:['Title'], pred:['Title'], token: .
# true:['Author'], pred:['Author'], token: Bajaj
# true:['Author'], pred:['Author'], token: M
# true:[], pred:[], token: (
# true:[], pred:[], token: 1
# true:[], pred:[], token: )
# true:[], pred:[], token: ,
# true:['Author'], pred:['Author'], token: Gilman
# true:['Author'], pred:['Author'], token: R
# true:[], pred:[], token: ,
# true:['Author'], pred:['Author'], token: Patel
# true:['Author'], pred:['Author'], token: S
# true:[], pred:[], token: ,
# true:['Author'], pred:['Author'], token: Kempthorne
# true:['Author'], pred:['Author'], token: -
# true:['Author'], pred:['Author'], token: Rawson
# true:['Author'], pred:['Author'], token: J
# true:[], pred:[], token: ,
# true:['Author'], pred:['Author'], token: Lewis
# true:['Author'], pred:['Author'], token: -
# true:['Author'], pred:['Author'], token: D
# true:['Author'], pred:['Author'], token: '
# true:['Author'], pred:['Author'], token: Agostino
# true:['Author'], pred:['Author'], token: D
# true:[], pred:[], token: ,
# true:['Author'], pred:['Author'], token: Woerle
# true:['Author'], pred:['Author'], token: HJ
# true:[], pred:[], token: .
# true:[], pred:[], token: Author
# true:[], pred:[], token: information
# true:[], pred:[], token: :
# true:[], pred:[], token: (
# true:[], pred:[], token: 1
# true:[], pred:[], token: )
# true:[], pred:[], token: Baylor
# true:[], pred:[], token: College
# true:[], pred:[], token: of
# true:[], pred:[], token: Medicine
# true:[], pred:[], token: ,
# true:[], pred:[], token: Houston
# true:[], pred:[], token: ,
# true:[], pred:[], token: TX
# true:[], pred:[], token: .
# true:[], pred:[], token: AIMS
# true:[], pred:[], token: :
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: To
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: investigate
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: the
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: efficacy
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: and
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: safety
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: of
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: the
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: dipeptidyl
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: peptidase
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: -
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: 4
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: inhibitor
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: linagliptin
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: in
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: patients
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: with
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: Type
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token:
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: 2
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: diabetes
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: mellitus
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: inadequately
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: controlled
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: by
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: a
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: combination
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: of
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: metformin
# true:['ObjectiveDescription', 'Precondition'], pred:['ObjectiveDescription'], token: and
# true:['ObjectiveDescription'], pred:['ObjectiveDescription'], token: pioglitazone
# true:[], pred:[], token: .
# true:[], pred:[], token: METHODS
# true:[], pred:[], token: :
# true:[], pred:[], token: This
# true:[], pred:[], token: was
# true:[], pred:[], token: a
# true:[], pred:[], token: multi
# true:[], pred:[], token: -
# true:[], pred:[], token: centre
# true:[], pred:[], token: ,
# true:[], pred:[], token: phase
# true:[], pred:[], token:
# true:[], pred:[], token: 3
# true:[], pred:[], token: ,
# true:[], pred:[], token: randomized
# true:[], pred:[], token: ,
# true:[], pred:[], token: double
# true:[], pred:[], token: -
# true:[], pred:[], token: blind
# true:[], pred:[], token: ,
# true:[], pred:[], token: placebo
# true:[], pred:[], token: -
# true:[], pred:[], token: controlled
# true:[], pred:[], token: study
# true:['DoseValue'], pred:['DoseValue'], token: comparing
# true:[], pred:[], token: linagliptin
# true:['Frequency'], pred:['Frequency'], token: 5
# true:['Frequency'], pred:['Frequency'], token:
# true:[], pred:[], token: mg
# true:[], pred:[], token: once
# true:[], pred:[], token: daily
# true:['NumberPatientsArm'], pred:['NumberPatientsArm'], token: (
# true:[], pred:[], token: n
# true:[], pred:[], token: =
# true:[], pred:[], token: 183
# true:[], pred:[], token: )
# true:[], pred:[], token: and
# true:[], pred:[], token: placebo
# true:['NumberPatientsArm'], pred:['NumberPatientsArm'], token: (
# true:[], pred:[], token: n
# true:[], pred:[], token: =
# true:[], pred:[], token: 89
# true:[], pred:[], token: )
# true:[], pred:[], token: as
# true:[], pred:[], token: add
# true:[], pred:[], token: -
# true:[], pred:[], token: on
# true:[], pred:[], token: to
# true:[], pred:[], token: metformin
# true:[], pred:[], token: and
# true:[], pred:[], token: pioglitazone
# true:[], pred:[], token: .
# true:[], pred:[], token: The
# true:[], pred:[], token: primary
# true:[], pred:[], token: endpoint
# true:[], pred:[], token: was
# true:['TimePoint'], pred:[], token: the
# true:[], pred:[], token: change
# true:[], pred:[], token: from
# true:[], pred:[], token: baseline
# true:[], pred:[], token: in
# true:[], pred:[], token: glycated
# true:[], pred:[], token: haemoglobin
# true:[], pred:[], token: (
# true:[], pred:[], token: HbA1c
# true:[], pred:[], token: )
# true:[], pred:[], token: after
# true:[], pred:[], token: 24
# true:[], pred:[], token:
# true:[], pred:[], token: weeks
# true:[], pred:[], token: .
# true:[], pred:[], token: RESULTS
# true:[], pred:[], token: :
# true:[], pred:[], token: The
# true:[], pred:[], token: placebo
# true:[], pred:[], token: -
# true:[], pred:[], token: corrected
# true:[], pred:[], token: adjusted
# true:[], pred:[], token: mean
# true:[], pred:[], token: (
# true:[], pred:[], token: se
# true:[], pred:[], token: )
# true:[], pred:[], token: change
# true:[], pred:[], token: in
# true:[], pred:[], token: HbA1c
# true:[], pred:[], token: from
# true:[], pred:[], token: baseline
# true:['DiffGroupAbsValue'], pred:[], token: to
# true:['DiffGroupAbsValue'], pred:[], token: 24
# true:[], pred:[], token:
# true:[], pred:[], token: weeks
# true:[], pred:[], token: was
# true:[], pred:[], token: -
# true:[], pred:[], token: 6
# true:[], pred:[], token: (
# true:[], pred:[], token: 1
# true:[], pred:[], token: )
# true:[], pred:[], token: mmol
# true:[], pred:[], token: /
# true:[], pred:[], token: mol
# true:[], pred:[], token: [
# true:[], pred:[], token: -
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:[], pred:[], token: 57
# true:[], pred:[], token: (
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:['PvalueDiff'], pred:['PvalueDiff'], token: 13
# true:['PvalueDiff'], pred:['PvalueDiff'], token: )
# true:['PvalueDiff'], pred:['PvalueDiff'], token: %
# true:['PvalueDiff'], pred:['PvalueDiff'], token: ]
# true:['PvalueDiff'], pred:['PvalueDiff'], token: (
# true:[], pred:[], token: P
# true:[], pred:[], token: <
# true:[], pred:[], token: 0
# true:['SubGroupDescription'], pred:[], token: .
# true:['SubGroupDescription'], pred:[], token: 0001
# true:['SubGroupDescription'], pred:[], token: )
# true:['SubGroupDescription'], pred:[], token: .
# true:['SubGroupDescription'], pred:[], token: In
# true:['SubGroupDescription'], pred:[], token: patients
# true:['SubGroupDescription'], pred:[], token: with
# true:['SubGroupDescription'], pred:[], token: baseline
# true:['SubGroupDescription'], pred:[], token: HbA1c
# true:[], pred:[], token: ≥
# true:[], pred:[], token: 53
# true:[], pred:[], token:
# true:[], pred:[], token: mmol
# true:[], pred:[], token: /
# true:[], pred:[], token: mol
# true:[], pred:[], token: (
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 7
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 0
# true:[], pred:[], token: %
# true:[], pred:[], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: 32
# true:[], pred:[], token: .
# true:[], pred:[], token: 4
# true:[], pred:[], token: %
# true:[], pred:[], token: of
# true:['PercentageAffected'], pred:['PercentageAffected'], token: patients
# true:['PercentageAffected'], pred:['PercentageAffected'], token: in
# true:['PercentageAffected'], pred:[], token: the
# true:[], pred:[], token: linagliptin
# true:[], pred:[], token: group
# true:[], pred:[], token: and
# true:[], pred:[], token: 13
# true:[], pred:[], token: .
# true:[], pred:[], token: 8
# true:[], pred:[], token: %
# true:[], pred:[], token: in
# true:[], pred:[], token: the
# true:[], pred:[], token: placebo
# true:[], pred:[], token: group
# true:[], pred:[], token: achieved
# true:[], pred:[], token: HbA1c
# true:[], pred:[], token: <
# true:[], pred:[], token: 53
# true:[], pred:[], token:
# true:[], pred:[], token: mmol
# true:[], pred:[], token: /
# true:[], pred:[], token: mol
# true:[], pred:[], token: (
# true:[], pred:[], token: 7
# true:['DiffGroupAbsValue'], pred:[], token: .
# true:['DiffGroupAbsValue'], pred:[], token: 0
# true:['DiffGroupAbsValue'], pred:[], token: %
# true:[], pred:[], token: )
# true:['PvalueDiff'], pred:['PvalueDiff'], token: (
# true:['PvalueDiff'], pred:['PvalueDiff'], token: odds
# true:['PvalueDiff'], pred:['PvalueDiff'], token: ratio
# true:['PvalueDiff'], pred:['PvalueDiff'], token:
# true:['PvalueDiff'], pred:['PvalueDiff'], token: 2
# true:[], pred:[], token: .
# true:[], pred:[], token: 94
# true:[], pred:[], token: ;
# true:[], pred:[], token: P
# true:[], pred:[], token: =
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:[], pred:[], token: 0033
# true:[], pred:[], token: )
# true:[], pred:[], token: .
# true:[], pred:[], token: The
# true:[], pred:[], token: placebo
# true:[], pred:[], token: -
# true:[], pred:[], token: corrected
# true:[], pred:[], token: adjusted
# true:[], pred:[], token: mean
# true:[], pred:[], token: (
# true:[], pred:[], token: se
# true:[], pred:[], token: )
# true:['TimePoint'], pred:[], token: change
# true:['TimePoint'], pred:[], token: from
# true:[], pred:[], token: baseline
# true:['DiffGroupAbsValue'], pred:[], token: in
# true:['DiffGroupAbsValue'], pred:[], token: fasting
# true:['DiffGroupAbsValue'], pred:[], token: plasma
# true:['DiffGroupAbsValue'], pred:[], token: glucose
# true:[], pred:[], token: at
# true:[], pred:['SdDevResValue'], token: week
# true:[], pred:['SdDevResValue'], token:
# true:[], pred:['SdDevResValue'], token: 24
# true:[], pred:[], token: was
# true:[], pred:[], token: -
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:[], pred:[], token: 57
# true:[], pred:[], token: (
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:[], pred:[], token: 26
# true:[], pred:[], token: )
# true:[], pred:[], token: mmol
# true:[], pred:[], token: /
# true:[], pred:[], token: l
# true:[], pred:[], token: [
# true:[], pred:[], token: -
# true:[], pred:[], token: 10
# true:[], pred:[], token: .
# true:[], pred:[], token: 4
# true:[], pred:[], token: (
# true:['PvalueDiff'], pred:['PvalueDiff'], token: 4
# true:['PvalueDiff'], pred:['PvalueDiff'], token: .
# true:['PvalueDiff'], pred:['PvalueDiff'], token: 7
# true:['PvalueDiff'], pred:['PvalueDiff'], token: )
# true:['PvalueDiff'], pred:['PvalueDiff'], token: mg
# true:[], pred:[], token: /
# true:[], pred:[], token: dl
# true:[], pred:[], token: ]
# true:[], pred:[], token: (
# true:[], pred:[], token: P
# true:[], pred:[], token: =
# true:[], pred:[], token: 0
# true:[], pred:[], token: .
# true:[], pred:[], token: 0280
# true:['PercentageAffected'], pred:['PercentageAffected'], token: )
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:['PercentageAffected'], pred:['PercentageAffected'], token: The
# true:[], pred:[], token: incidence
# true:[], pred:[], token: of
# true:[], pred:[], token: serious
# true:[], pred:[], token: adverse
# true:['PercentageAffected'], pred:['PercentageAffected'], token: events
# true:['PercentageAffected'], pred:['PercentageAffected'], token: was
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 2
# true:[], pred:[], token: .
# true:[], pred:[], token: 2
# true:[], pred:[], token: %
# true:[], pred:[], token: with
# true:[], pred:[], token: linagliptin
# true:[], pred:[], token: and
# true:[], pred:[], token: 3
# true:[], pred:[], token: .
# true:[], pred:[], token: 4
# true:[], pred:[], token: %
# true:['PercentageAffected'], pred:['PercentageAffected'], token: with
# true:['PercentageAffected'], pred:['PercentageAffected'], token: placebo
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:[], pred:[], token: Investigator
# true:[], pred:[], token: -
# true:[], pred:[], token: defined
# true:[], pred:[], token: hypoglycaemia
# true:[], pred:[], token: occurred
# true:[], pred:[], token: in
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 5
# true:['PercentageAffected'], pred:['PercentageAffected'], token: .
# true:['PercentageAffected'], pred:['PercentageAffected'], token: 5
# true:[], pred:[], token: %
# true:[], pred:[], token: of
# true:[], pred:[], token: the
# true:[], pred:[], token: linagliptin
# true:[], pred:[], token: group
# true:[], pred:[], token: and
# true:[], pred:[], token: 5
# true:[], pred:['ObservedResult'], token: .
# true:[], pred:['ObservedResult'], token: 6
# true:[], pred:[], token: %
# true:[], pred:[], token: of
# true:[], pred:[], token: the
# true:[], pred:[], token: placebo
# true:[], pred:[], token: group
# true:[], pred:[], token: .
# true:[], pred:[], token: No
# true:[], pred:[], token: meaningful
# true:[], pred:[], token: changes
# true:[], pred:[], token: in
# true:[], pred:[], token: mean
# true:[], pred:[], token: body
# true:['ConclusionComment'], pred:['ConclusionComment'], token: weight
# true:['ConclusionComment'], pred:['ConclusionComment'], token: were
# true:['ConclusionComment'], pred:['ConclusionComment'], token: noted
# true:['ConclusionComment'], pred:['ConclusionComment'], token: for
# true:['ConclusionComment'], pred:['ConclusionComment'], token: either
# true:['ConclusionComment'], pred:['ConclusionComment'], token: group
# true:['ConclusionComment'], pred:['ConclusionComment'], token: .
# true:['ConclusionComment'], pred:['ConclusionComment'], token: CONCLUSIONS
# true:['ConclusionComment'], pred:['ConclusionComment'], token: :
# true:['ConclusionComment'], pred:['ConclusionComment'], token: Linagliptin
# true:['ConclusionComment'], pred:['ConclusionComment'], token: as
# true:['ConclusionComment'], pred:['ConclusionComment'], token: add
# true:['ConclusionComment'], pred:['ConclusionComment'], token: -
# true:['ConclusionComment'], pred:['ConclusionComment'], token: on
# true:['ConclusionComment'], pred:['ConclusionComment'], token: therapy
# true:['ConclusionComment'], pred:['ConclusionComment'], token: to
# true:['ConclusionComment'], pred:['ConclusionComment'], token: metformin
# true:['ConclusionComment'], pred:['ConclusionComment'], token: and
# true:['ConclusionComment'], pred:['ConclusionComment'], token: pioglitazone
# true:['ConclusionComment'], pred:['ConclusionComment'], token: produced
# true:['ConclusionComment'], pred:['ConclusionComment'], token: significant
# true:['ConclusionComment'], pred:['ConclusionComment'], token: and
# true:['ConclusionComment'], pred:['ConclusionComment'], token: clinically
# true:['ConclusionComment'], pred:['ConclusionComment'], token: meaningful
# true:['ConclusionComment'], pred:['ConclusionComment'], token: improvements
# true:['ConclusionComment'], pred:['ConclusionComment'], token: in
# true:['ConclusionComment'], pred:['ConclusionComment'], token: glycaemic
# true:['ConclusionComment'], pred:['ConclusionComment'], token: control
# true:['ConclusionComment'], pred:['ConclusionComment'], token: ,
# true:['ConclusionComment'], pred:['ConclusionComment'], token: without
# true:['ConclusionComment'], pred:['ConclusionComment'], token: an
# true:['ConclusionComment'], pred:['ConclusionComment'], token: additional
# true:['ConclusionComment'], pred:['ConclusionComment'], token: risk
# true:['ConclusionComment'], pred:['ConclusionComment'], token: of
# true:['ConclusionComment'], pred:['ConclusionComment'], token: hypoglycaemia
# true:['ConclusionComment'], pred:['ConclusionComment'], token: or
# true:['ConclusionComment'], pred:[], token: weight
# true:['ConclusionComment'], pred:['ConclusionComment'], token: gain
# true:['ConclusionComment'], pred:['ConclusionComment'], token: (
# true:[], pred:[], token: Clinical
# true:[], pred:[], token: Trials
# true:[], pred:[], token: Registry
# true:[], pred:[], token: No
# true:[], pred:[], token: :
# true:[], pred:[], token: NCT
# true:[], pred:[], token: 00996658
# true:[], pred:[], token: )
# true:[], pred:[], token: .
# true:[], pred:[], token: ©
# true:[], pred:[], token: 2014
# true:[], pred:[], token: The
# true:[], pred:[], token: Authors
# true:[], pred:[], token: .
# true:[], pred:[], token: Diabetic
# true:[], pred:[], token: Medicine
# true:[], pred:[], token: published
# true:[], pred:[], token: by
# true:[], pred:[], token: John
# true:[], pred:[], token: Wiley
# true:[], pred:[], token: &
# true:[], pred:[], token: Sons
# true:[], pred:[], token: Ltd
# true:[], pred:[], token: on
# true:[], pred:[], token: behalf
# true:[], pred:[], token: of
# true:[], pred:[], token: Diabetes
# true:[], pred:[], token: UK
# true:[], pred:[], token: .
# true:[], pred:[], token: DOI
# true:[], pred:[], token: :
# true:[], pred:[], token: 10
# true:[], pred:[], token: .
# true:[], pred:[], token: 1111
# true:['PMID'], pred:['PMID'], token: /
# true:[], pred:[], token: dme
# true:[], pred:[], token: .
# true:[], pred:[], token: 12495
# true:[], pred:[], token: PMCID
# true:[], pred:[], token: :
# true:['Journal'], pred:['Journal'], token: PMC4257097
# true:['Journal'], pred:['Journal'], token: PMID
# true:[], pred:[], token: :
# true:['PublicationYear'], pred:['PublicationYear'], token: 24824197
# true:[], pred:[], token: [
# true:[], pred:[], token: Indexed
# true:[], pred:[], token: for
# true:[], pred:[], token: MEDLINE
# true:[], pred:[], token: ]
# true:[], pred:[], token: Diabetes
# true:[], pred:[], token: Care
# true:[], pred:[], token: .
# true:[], pred:[], token: 2014
# true:[], pred:[], token: Nov
# true:[], pred:[], token: ;
# true:[], pred:[], token: 37
# true:[], pred:[], token: (
# true:[], pred:[], token: 11
# true:[], pred:[], token: )
# true:[], pred:[], token: :
# true:[], pred:[], token: 3121
# true:[], pred:[], token: -
# true:[], pred:[], token: 3
# true:[], pred:[], token: .
# true:[], pred:[], token: doi
# true:[], pred:[], token: :
# true:[], pred:[], token: 10
# true:[], pred:[], token: .
# true:[], pred:[], token: 2337
# true:[], pred:[], token: /
# true:['Title'], pred:['Title'], token: dc14
# true:['Title'], pred:['Title'], token: -
# true:['Title'], pred:['Title'], token: 1038
# true:['Title'], pred:['Title'], token: .
# true:['Title'], pred:['Title'], token: Epub
# true:['Title'], pred:['Title'], token: 2014
# true:['Title'], pred:['Title'], token: Aug
# true:['Title'], pred:['Title'], token: 14
# true:['Title'], pred:['Title'], token: .
# true:['Title'], pred:['Title'], token: Efficacy
# true:['Title'], pred:['Title'], token: and
# true:['Title'], pred:['Title'], token: safety
# true:['Title'], pred:['Title'], token: of
# true:['Title'], pred:['Title'], token: oral
# true:['Title'], pred:['Title'], token: methazolamide
# true:['Title'], pred:['Title'], token: in
# true:['Title'], pred:['Title'], token: patients
# true:['Title'], pred:['Title'], token: with
# true:['Title'], pred:['Title'], token: type
# true:['Title'], pred:['Title'], token: 2
# true:['Title'], pred:['Title'], token: diabetes
# true:['Title'], pred:['Title'], token: :
# true:['Title'], pred:['Title'], token: a
# true:['Title'], pred:['Title'], token: 24
# true:['Title'], pred:['Title'], token: -
# true:['Title'], pred:['Title'], token: week
# true:['Title'], pred:['Title'], token: ,
# true:['Author'], pred:['Author'], token: placebo
# true:['Author'], pred:['Author'], token: -
# true:[], pred:[], token: controlled
# true:[], pred:[], token: ,
# true:[], pred:[], token: double
# true:[], pred:[], token: -
# true:['Author'], pred:['Author'], token: blind
# true:['Author'], pred:['Author'], token: study
# true:[], pred:[], token: .
# true:[], pred:[], token: Simpson
# true:[], pred:[], token: RW
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 1
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Nicholson
# true:[], pred:[], token: GC
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 2
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Proietto
# true:[], pred:[], token: J
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 3
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Sarah
# true:[], pred:[], token: A
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 4
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Sanders
# true:[], pred:[], token: KM
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 2
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Phillips
# true:[], pred:[], token: G
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 1
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Chambers
# true:[], pred:[], token: J
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 4
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: MacGinley
# true:[], pred:[], token: R
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 5
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Orford
# true:[], pred:[], token: N
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 6
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Walder
# true:[], pred:[], token: K
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 5
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Krippner
# true:[], pred:[], token: G
# true:[], pred:[], token: (
# true:['Author'], pred:['Author'], token: 7
# true:['Author'], pred:['Author'], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Skoff
# true:[], pred:[], token: K
# true:[], pred:[], token: (
# true:[], pred:[], token: 7
# true:[], pred:[], token: )
# true:[], pred:[], token: ,
# true:[], pred:[], token: Wacher
# true:[], pred:[], token: VJ
# true:[], pred:[], token: (
# true:[], pred:[], token: 8
# true:[], pred:[], token: )
# true:[], pred:[], token: .
# true:[], pred:[], token: Author
# true:[], pred:[], token: information
# true:[], pred:[], token: :
# true:[], pred:[], token: (
# true:[], pred:[], token: 1
# true:[], pred:[], token: )
# true:[], pred:[], token: Box
# true:[], pred:[], token: Hill
# Micro-F1 Score: 0.905
